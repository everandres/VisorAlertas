# %%
import pandas as pd
import geopandas as gpd
from pymongo import MongoClient
import json

# %%
df_incendios = pd.read_csv('probabilidad_icv.csv', sep = ';', encoding = 'utf-8')

# %%
df_incendios
# Out:
#         REGION     DEPARTAMENTO       MUNICIPIO  COD_DANE  PROBABILIDAD  \
# 0       ANDINA        ANTIOQUIA       ABEJORRAL      5002             3
# 1       ANDINA        ANTIOQUIA           AMAGÁ      5030             3
# 2       ANDINA        ANTIOQUIA          AMALFI      5031             3
# 3       ANDINA        ANTIOQUIA           ANDES      5034             3
# 4       ANDINA        ANTIOQUIA     ANGELÓPOLIS      5036             3
# ..         ...              ...             ...       ...           ...
# 798   PACÍFICO  VALLE DEL CAUCA      EL CERRITO     76248             2
# 799   PACÍFICO  VALLE DEL CAUCA         JAMUNDÍ     76364             2
# 800   PACÍFICO  VALLE DEL CAUCA         PALMIRA     76520             2
# 801   PACÍFICO  VALLE DEL CAUCA           YUMBO     76892             2
# 802  ORINOQUÍA          VICHADA  PUERTO CARREÑO     99001             2
#
#     FECHA_EJECUCION
# 0         4/12/2023
# 1         4/12/2023
# 2         4/12/2023
# ...

# %%
df_incendios.dtypes
# Out:
# REGION             object
# DEPARTAMENTO       object
# MUNICIPIO          object
# COD_DANE            int64
# PROBABILIDAD        int64
# FECHA_EJECUCION    object
# dtype: object

# %%
departamentos_shp = gpd.read_file(r'O:\Mi unidad\OSPA\01. Tematicas\04. Incendios\01. Productos\postmodelo_icv\insumos\shapefiles\MGN_MPIO_POLITICO.shp')

# %%
departamentos_shp
# Out:
#      DPTO_CCDGO MPIO_CCDGO  MPIO_CDPMP DPTO_CNMBR        MPIO_CNMBR  \
# 0            97        001       97001     VAUPÉS              MITÚ
# 1            97        161       97161     VAUPÉS            CARURÚ
# 2            97        511       97511     VAUPÉS             PACOA
# 3            97        666       97666     VAUPÉS           TARAIRA
# 4            97        777       97777     VAUPÉS         PAPUNAHUA
# ...         ...        ...         ...        ...               ...
# 1116         91        530       91530   AMAZONAS    PUERTO ALEGRÍA
# 1117         91        536       91536   AMAZONAS      PUERTO ARICA
# 1118         91        540       91540   AMAZONAS     PUERTO NARIÑO
# 1119         91        669       91669   AMAZONAS  PUERTO SANTANDER
# 1120         91        798       91798   AMAZONAS          TARAPACÁ
#
#                                     MPIO_CRSLC    MPIO_NAREA MPIO_CSMBL  \
# 0     Decreto Nal 1666 del 6 de Agosto de 1974  16215.737264          4
# ...

# %%
departamentos_shp.dtypes
# Out:
# DPTO_CCDGO      object
# MPIO_CCDGO      object
# MPIO_CDPMP       int64
# DPTO_CNMBR      object
# MPIO_CNMBR      object
# MPIO_CRSLC      object
# MPIO_NAREA     float64
# MPIO_CSMBL      object
# MPIO_VGNC        int64
# MPIO_TIPO       object
# Shape_Leng     float64
# Shape_Area     float64
# REGION          object
# geometry      geometry
# dtype: object

# %%
departamentos_geometry = departamentos_shp[['MPIO_CDPMP', 'geometry']]

# %%
merged_df = df_incendios.merge(departamentos_geometry, left_on='COD_DANE', right_on='MPIO_CDPMP', how='left')

# %%
merged_df
# Out:
#         REGION     DEPARTAMENTO       MUNICIPIO  COD_DANE  PROBABILIDAD  \
# 0       ANDINA        ANTIOQUIA       ABEJORRAL      5002             3
# 1       ANDINA        ANTIOQUIA           AMAGÁ      5030             3
# 2       ANDINA        ANTIOQUIA          AMALFI      5031             3
# 3       ANDINA        ANTIOQUIA           ANDES      5034             3
# 4       ANDINA        ANTIOQUIA     ANGELÓPOLIS      5036             3
# ..         ...              ...             ...       ...           ...
# 798   PACÍFICO  VALLE DEL CAUCA      EL CERRITO     76248             2
# 799   PACÍFICO  VALLE DEL CAUCA         JAMUNDÍ     76364             2
# 800   PACÍFICO  VALLE DEL CAUCA         PALMIRA     76520             2
# 801   PACÍFICO  VALLE DEL CAUCA           YUMBO     76892             2
# 802  ORINOQUÍA          VICHADA  PUERTO CARREÑO     99001             2
#
#     FECHA_EJECUCION  MPIO_CDPMP  \
# 0         4/12/2023        5002
# 1         4/12/2023        5030
# ...

# %%
merged_df.drop('MPIO_CDPMP', axis=1, inplace=True)

# %%
merged_df
# Out:
#         REGION     DEPARTAMENTO       MUNICIPIO  COD_DANE  PROBABILIDAD  \
# 0       ANDINA        ANTIOQUIA       ABEJORRAL      5002             3
# 1       ANDINA        ANTIOQUIA           AMAGÁ      5030             3
# 2       ANDINA        ANTIOQUIA          AMALFI      5031             3
# 3       ANDINA        ANTIOQUIA           ANDES      5034             3
# 4       ANDINA        ANTIOQUIA     ANGELÓPOLIS      5036             3
# ..         ...              ...             ...       ...           ...
# 798   PACÍFICO  VALLE DEL CAUCA      EL CERRITO     76248             2
# 799   PACÍFICO  VALLE DEL CAUCA         JAMUNDÍ     76364             2
# 800   PACÍFICO  VALLE DEL CAUCA         PALMIRA     76520             2
# 801   PACÍFICO  VALLE DEL CAUCA           YUMBO     76892             2
# 802  ORINOQUÍA          VICHADA  PUERTO CARREÑO     99001             2
#
#     FECHA_EJECUCION                                           geometry
# ...

# %%
# Convertir el GeoDataFrame a un formato de diccionario
merged_df['geometry'] = merged_df['geometry'].apply(lambda x: x.__geo_interface__)

# %%
merged_df
# Out:
#         REGION     DEPARTAMENTO       MUNICIPIO  COD_DANE  PROBABILIDAD  \
# 0       ANDINA        ANTIOQUIA       ABEJORRAL      5002             3
# 1       ANDINA        ANTIOQUIA           AMAGÁ      5030             3
# 2       ANDINA        ANTIOQUIA          AMALFI      5031             3
# 3       ANDINA        ANTIOQUIA           ANDES      5034             3
# 4       ANDINA        ANTIOQUIA     ANGELÓPOLIS      5036             3
# ..         ...              ...             ...       ...           ...
# 798   PACÍFICO  VALLE DEL CAUCA      EL CERRITO     76248             2
# 799   PACÍFICO  VALLE DEL CAUCA         JAMUNDÍ     76364             2
# 800   PACÍFICO  VALLE DEL CAUCA         PALMIRA     76520             2
# 801   PACÍFICO  VALLE DEL CAUCA           YUMBO     76892             2
# 802  ORINOQUÍA          VICHADA  PUERTO CARREÑO     99001             2
#
#     FECHA_EJECUCION                                           geometry
# ...

# %%
df_incendios
# Out:
#         REGION     DEPARTAMENTO       MUNICIPIO  COD_DANE  PROBABILIDAD  \
# 0       ANDINA        ANTIOQUIA       ABEJORRAL      5002             3
# 1       ANDINA        ANTIOQUIA           AMAGÁ      5030             3
# 2       ANDINA        ANTIOQUIA          AMALFI      5031             3
# 3       ANDINA        ANTIOQUIA           ANDES      5034             3
# 4       ANDINA        ANTIOQUIA     ANGELÓPOLIS      5036             3
# ..         ...              ...             ...       ...           ...
# 798   PACÍFICO  VALLE DEL CAUCA      EL CERRITO     76248             2
# 799   PACÍFICO  VALLE DEL CAUCA         JAMUNDÍ     76364             2
# 800   PACÍFICO  VALLE DEL CAUCA         PALMIRA     76520             2
# 801   PACÍFICO  VALLE DEL CAUCA           YUMBO     76892             2
# 802  ORINOQUÍA          VICHADA  PUERTO CARREÑO     99001             2
#
#     FECHA_EJECUCION
# 0         4/12/2023
# 1         4/12/2023
# 2         4/12/2023
# ...

# %%
# Convertir el GeoDataFrame a un diccionario
data_to_insert = df_incendios.to_dict('records')

# %%
data_to_insert
# Out:
# [{'REGION': 'ANDINA',
#   'DEPARTAMENTO': 'ANTIOQUIA',
#   'MUNICIPIO': 'ABEJORRAL',
#   'COD_DANE': 5002,
#   'PROBABILIDAD': 3,
#   'FECHA_EJECUCION': '4/12/2023'},
#  {'REGION': 'ANDINA',
#   'DEPARTAMENTO': 'ANTIOQUIA',
#   'MUNICIPIO': 'AMAGÁ',
#   'COD_DANE': 5030,
#   'PROBABILIDAD': 3,
#   'FECHA_EJECUCION': '4/12/2023'},
#  {'REGION': 'ANDINA',
#   'DEPARTAMENTO': 'ANTIOQUIA',
#   'MUNICIPIO': 'AMALFI',
#   'COD_DANE': 5031,
#   'PROBABILIDAD': 3,
#   'FECHA_EJECUCION': '4/12/2023'},
#  {'REGION': 'ANDINA',
#   'DEPARTAMENTO': 'ANTIOQUIA',
#   'MUNICIPIO': 'ANDES',
#   'COD_DANE': 5034,
#   'PROBABILIDAD': 3,
#   'FECHA_EJECUCION': '4/12/2023'},
#  {'REGION': 'ANDINA',
#   'DEPARTAMENTO': 'ANTIOQUIA',
#   'MUNICIPIO': 'ANGELÓPOLIS',
#   'COD_DANE': 5036,
#   'PROBABILIDAD': 3,
#   'FECHA_EJECUCION': '4/12/2023'},
#  {'REGION': 'ANDINA',
#   'DEPARTAMENTO': 'ANTIOQUIA',
#   'MUNICIPIO': 'ANZÁ',
#   'COD_DANE': 5044,
#   'PROBABILIDAD': 3,
#   'FECHA_EJECUCION': '4/12/2023'},
# ...

# %%
# Conectar a MongoDB
client = MongoClient('mongodb+srv://everandres:MmQHUK199Hz3sKRg@ospa.jtty6om.mongodb.net')
db = client['alertas']
collection = db['incendios']

# Insertar los datos en MongoDB
collection.insert_many(data_to_insert)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# <ipython-input-7-db39fa70c685> in <module>
#       5
#       6 # Insertar los datos en MongoDB
# ----> 7 collection.insert_many(data_to_insert)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\_csot.py in csot_wrapper(self, *args, **kwargs)
#     105                 with _TimeoutContext(timeout):
#     106                     return func(self, *args, **kwargs)
# --> 107         return func(self, *args, **kwargs)
#     108
#     109     return cast(F, csot_wrapper)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     753         blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     754         blk.ops = list(gen())
# --> 755         blk.execute(write_concern, session=session)
# ...
